# %%
import logging

if __name__ == '__main__':
    logger = logging.getLogger("main")
    #logging.basicConfig(level=logging.DEBUG)
    logger.setLevel(logging.info)




    logger.debug("틀렸어")
    logger.info("확인해")
    logger.warning("조심해")
    logger.error("에러났어")
    logger.critical("망했다")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 6
#       4 logger = logging.getLogger("main")
#       5 #logging.basicConfig(level=logging.DEBUG)
# ----> 6 logger.setLevel(logging.info)
#      11 logger.debug("틀렸어")
#      12 logger.info("확인해")
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py:1495, in Logger.setLevel(self, level)
#    1491 def setLevel(self, level):
#    1492     """
#    1493     Set the logging level of this logger.  level must be an int or a str.
#    1494     """
# -> 1495     self.level = _checkLevel(level)
#    1496     self.manager._clear_cache()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\logging\__init__.py:213, in _checkLevel(level)
#     211     rv = _nameToLevel[level]
#     212 else:
# --> 213     raise TypeError("Level not an integer or a valid string: %r"
#     214                     % (level,))
#     215 return rv
#
# TypeError: Level not an integer or a valid string: <function info at 0x00000201753E4040>
