# %%
import os
os.mkdir("suhwan")

# %% [raw]
# try:
#     os.mkdir("suhwan")
# except FileExistsError as e:
#     print("Already created")

# %%
try:
    os.mkdir("suhwan")
except FileExistsError as e:
    print("Already created")
# Out:
# Already created

# %%
os.path.exists("suhwan")
# Out:
# True

# %%
os.path.isfile("suhwan")
# Out:
# False

# %%
import pickle
f = open("list.pickle", "wb")
test = [1,2,3,4,5]
pickle.dump(test, f)
f.close()

# %%
test
# Out:
# [1, 2, 3, 4, 5]

# %%
test_pickle = 0
test_pickle
# Out:
# 0

# %%
del test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 del test
#
# NameError: name 'test' is not defined

# %%
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 test
#
# NameError: name 'test' is not defined

# %%
f = open("list.pickle", "rb")
test_pickle = pickle.load(f)
test_pickle
f.close()

# %%
test_pickle
# Out:
# 0

# %%
class Multiply(object):
    def __init__(self, multiplier):
        self.multiplier = multiplier

    def multiply(self, number):
        return number * self.multiplier

# %%
mulitply = Multiply(5)
mulitply.multiply(100)
# Out:
# 500

# %%
del muliply
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 del muliply
#
# NameError: name 'muliply' is not defined

# %%
f = open("multiply_object.pickle", "rb")
multiply_pickle = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 f = open("multiply_object.pickle", "rb")
#       2 multiply_pickle = pickle.load(f)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:344, in _modified_open(file, *args, **kwargs)
#     337 if file in {0, 1, 2}:
#     338     raise ValueError(
#     339         f"IPython won't let you open fd={file} by default "
#     340         "as it is likely to crash IPython. If you know what you are doing, "
#     341         "you can use builtins' open."
#     342     )
# --> 344 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'multiply_object.pickle'
