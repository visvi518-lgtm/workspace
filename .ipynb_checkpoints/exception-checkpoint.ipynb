# %%
a = [1,2,3,4,5]
for i in range(10):
    try:
        print(i, 10//i)
    except ZeroDivisionError:
        print("Not divided by 0")
# Out:
# Not divided by 0
# 1 10
# 2 5
# 3 3
# 4 2
# 5 2
# 6 1
# 7 1
# 8 1
# 9 1

# %%
from datetime import datetime

for i in range(10):
    try:
        print(i, 10 // i)
        a[i]
    except ZeroDivisionError as err:
        print(err)
        print("{} Not divided by 0".format(
            datetime.now()
        ))
    except Exception as e:
        print(e)
# Out:
# integer division or modulo by zero
# 2026-02-16 11:38:54.598801 Not divided by 0
# 1 10
# 2 5
# 3 3
# 4 2
# 5 2
# list index out of range
# 6 1
# list index out of range
# 7 1
# list index out of range
# 8 1
# list index out of range
# 9 1
# list index out of range

# %%
for i in range(10):
    try:
        result = 10//i
    except ZeroDivisionError:
        print("Not divided by 0")
    else:
        print(10//i)
# Out:
# Not divided by 0
# 10
# 5
# 3
# 2
# 2
# 1
# 1
# 1
# 1

# %%
for i in range(10):
    try:
        result = 10//i
    except ZeroDivisionError:
        print("Not divided by 0")
    else:
        print(10//i)
    finally:
        print(i,"-----", result)
# Out:
# Not divided by 0
# 0 ----- 1
# 10
# 1 ----- 10
# 5
# 2 ----- 5
# 3
# 3 ----- 3
# 2
# 4 ----- 2
# 2
# 5 ----- 2
# 1
# 6 ----- 1
# 1
# 7 ----- 1
# 1
# 8 ----- 1
# 1
# 9 ----- 1

# %%
a = [1,2,3,4,5]
for i in range(10):
    try:
        print(i, 10//i)
    except ZeroDivisionError:
        print("error")
        print("Not divided by 0")
# Out:
# error
# Not divided by 0
# 1 10
# 2 5
# 3 3
# 4 2
# 5 2
# 6 1
# 7 1
# 8 1
# 9 1

# %%
a = [1,2,3,4,5]
for i in range(10):
    try:
        print(i, 10//i)
        print(a[i])
    except ZeroDivisionError:
        print("error")
        print("Not divided by 0")
    except IndexError as e:
        print(e)
# Out:
# error
# Not divided by 0
# 1 10
# 2
# 2 5
# 3
# 3 3
# 4
# 4 2
# 5
# 5 2
# list index out of range
# 6 1
# list index out of range
# 7 1
# list index out of range
# 8 1
# list index out of range
# 9 1
# list index out of range

# %%
while True:
    value = input("변환할 정수값을 입력해주세요")
    for digit in value:
        if digit not in "0123456789":
            raise ValueError("숫자값을 입력하지 않았습니다")
    print("정수값으로 변환된 슛자 -", int(value))
# Out:
# 변환할 정수값을 입력해주세요
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 6
#       4     if digit not in "0123456789":
#       5         raise ValueError("숫자값을 입력하지 않았습니다")
# ----> 6 print("정수값으로 변환된 슛자 -", int(value))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
def get_binary_number(decimal_number : int):
    assert isinstance(decimal_number, int)
    return bin(decimal_number)

print(get_binary_number(10.0))
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[22], line 5
#       2     assert isinstance(decimal_number, int)
#       3     return bin(decimal_number)
# ----> 5 print(get_binary_number(10.0))
#
# Cell In[22], line 2, in get_binary_number(decimal_number)
#       1 def get_binary_number(decimal_number : int):
# ----> 2     assert isinstance(decimal_number, int)
#       3     return bin(decimal_number)
#
# AssertionError:
